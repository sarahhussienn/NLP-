# %% [markdown]
# # Spelling Check

# %%
# !pip install textblob
# !pip install pyspellchecker
# !pip install fuzzywuzzy
# !pip install python-Levenshtein
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: textblob in /usr/local/lib/python3.8/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.8/dist-packages (from textblob) (3.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob) (7.1.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.7.1-py3-none-any.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 25.1 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.7.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.20.9-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.20.9
#   Downloading Levenshtein-0.20.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.0/174.0 KB 4.4 MB/s eta 0:00:00
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.13.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 35.1 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.20.9 python-Levenshtein-0.20.9 rapidfuzz-2.13.7

# %%
from spellchecker import SpellChecker

spell = SpellChecker()

# find those words that may be misspelled
misspelled = spell.unknown(['something', 'is', 'hapenning', 'here'])

for word in misspelled:
    # Get the one `most likely` answer
    print("Correction",spell.correction(word))

    # Get a list of `likely` options
    print("Candidate",spell.candidates(word))
# Out:
# Correction happening
# Candidate {'henning', 'happening', 'penning'}

# %%
from textblob import TextBlob

a = "hapenning"		 # incorrect spelling
print("original text: "+str(a))

b = TextBlob(a)

# prints the corrected spelling
print("corrected text: "+str(b.correct()))
# Out:
# original text: hapenning
# corrected text: happening

# %% [markdown]
# Create your own Spelling Checker

# %%
# youssef sameh abdelazim 46-20316

# %%
#List of words in your vocab
data=[]
with open("clean_vocab.txt",'r',errors="ignore") as input_vocab:
  data=[word for word in input_vocab.readlines()]

# %%
# import the fuzzywuzzy module
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
# change all the words to lowercase
data = [i.lower().replace("\n","") for i in data]

# remove all the duplicates in the list
data = set(data)

# store all the words into a class variable dictionary
dictionary = list(data)

# %%
# string setter method
def check( string_to_check):
    # store the string to be checked in a class variable
    string_to_check = string_to_check

# %%
# this method returns the possible suggestions of the correct words
def suggestions(string_to_check):
    # store the words of the string to be checked in a list by using a split function
    string_words = string_to_check.split()

    # a list to store all the possible suggestions
    suggestions = []

    # loop over the number of words in the string to be checked
    for i in range(len(string_words)):
        
        # loop over words in the dictionary
        for name in dictionary:
            
            # if the fuzzywuzzy returns the matched value greater than 80
            if fuzz.ratio(string_words[i].lower(), name.lower()) >= 75:
                # print("name",name)
                # print("Score",fuzz.ratio(string_words[i].lower(), name.lower()))
                # append the dict word to the suggestion list
                suggestions.append(name)

    # return the suggestions list
    return suggestions

# %%
# this method returns the corrected string of the given input
def correct(string_to_check):
    # store the words of the string to be checked in a list by using a split function
    string_words = string_to_check.split()

    # loop over the number of words in the string to be checked
    for i in range(len(string_words)):
        
        # initiaze a maximum probability variable to 0
        max_percent = 0

        # loop over the words in the dictionary
        for name in dictionary:
            
            # calulcate the match probability
            percent = fuzz.ratio(string_words[i].lower(), name.lower())
            
            # if the fuzzywuzzy returns the matched value greater than 80
            if percent >= 75:
                
                # if the matched probability is
                if percent > max_percent:
                    
                    # change the original value with the corrected matched value
                    string_words[i] = name
                
                # change the max percent to the current matched percent
                max_percent = percent
    
    # return the cprrected string
    return " ".join(string_words)

# %%
def correct2(string_to_check):
  # store the words of the string to be checked in a list by using a split function
    string_words = string_to_check.split()
    corrected_words=""
    # loop over the number of words in the string to be checked
    for word in string_words:
      
      correct=process.extractOne(word.lower(),dictionary, scorer=fuzz.token_sort_ratio)[0]
      
      corrected_words+=correct+" "
    return corrected_words
correct2("eeh a5brk")
# Out:
# 'eh a5bark '

# %%
string_to_be_checked = "eeh a5brkk"
check(string_to_be_checked)

# print suggestions and correction
print (suggestions(string_to_be_checked))
print (correct(string_to_be_checked))
# Out:
# name eh
# Score 80
# name a5bark
# Score 83
# name a5barek
# Score 77
# name a5barak
# Score 77
# name a5brak
# Score 83
# name a5rk
# Score 80
# ['eh', 'a5bark', 'a5barek', 'a5barak', 'a5brak', 'a5rk']
# eh a5brak

# %% [markdown]
# # VSM

# %% [markdown]
# **Bellow cell imports all the necessary libraries**

# %%
import glob
import nltk
nltk.download('popular');
from nltk.corpus import stopwords
from nltk import word_tokenize
import string
from collections import Counter
import numpy as np
from collections import OrderedDict
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular

# %% [markdown]
# **give_path: **function** **
#
# In below cell, give_path() takes path of the folder containing all the documents.
# give_path() then read all the documents and store content of each document (in string format) as 'value' of dictionary and it's file name as 'key' in the dictionary.
# This function the returns the dictionary containing all documents.

# %%
def give_path(fld_path):                             #give path of the folder containing all documents
    dic = {}
    file_names = glob.glob(fld_path)
    files_150 = file_names[0:10]
    for file in files_150:
        name = file.split('/')[-1]
        with open(file, 'r', errors='ignore') as f:
            data = f.read()
        dic[name] = data
    return dic

# %% [markdown]
# **wordList_removePuncs: **function** **
#
# In the below cell, two functions wordList() and removePuncs() functions have been combined as wordList_removePuncs.
# This function is passed with dictionary of all documents (returned by give_path()). Function then remove the stop words and punctuations and returns a list of all the words in our collection of documents. This list contains the redundant words.

# %%
def wordList_removePuncs(doc_dict):
    stop = stopwords.words('english') + list(string.punctuation) + ['\n']
    wordList = []
    for doc in doc_dict.values():
        for word in word_tokenize(doc.lower().strip()): 
            if not word in stop:
                wordList.append(word)
    return wordList

# %% [markdown]
# **termFrequencyInDoc: **function** **
#
# After the above function returns a list of all words in the collection of documents, vocabulary of words is made (I'm making vocabulary in 'main'). This vocabulary and collection of documents in dictionary form (returned by give_path) is passed to below function (termFrequencyInDoc) to find the frequency of words in each documet. This function returns a dictionary in which 'key' is the document name and its 'value' is another dicionary, containing a word as 'key' and its frequency as 'value'. It's actually a dictionary within a dictionary.

# %%
def termFrequencyInDoc(vocab, doc_dict):
    tf_docs = {}
    for doc_id in doc_dict.keys():
        tf_docs[doc_id] = {}
    
    for word in vocab:
        for doc_id,doc in doc_dict.items():
            tf_docs[doc_id][word] = doc.count(word)
    return tf_docs

# %% [markdown]
# **wordDocFre: **function** **
#
# To count the document frequency, vocabulary of words and dictionary of collection of documents if passed to wordDocFre which returns a dictionary containing a word as 'key' and its document frequency as 'value' of dictionary.

# %%
def wordDocFre(vocab, doc_dict):
    df = {}
    for word in vocab:
        frq = 0
        for doc in doc_dict.values():
#             if word in doc.lower().split():
            if word in word_tokenize(doc.lower().strip()):
                frq = frq + 1
        df[word] = frq
    return df

# %% [markdown]
# **inverseDocFre: **function** **
#
# inverseDocFre calculates the inverse document frequency. It takes vocabulary of words, dictionary of document frequency (returned by wordDocFre) and number of documents in our collection. It returns a dictionary containing inverse DF in which a word is key and its idf score is its value.

# %%
def inverseDocFre(vocab,doc_fre,length):
    idf= {} 
    for word in vocab:     
        idf[word] = np.log2((length+1) / doc_fre[word])
    return idf

# %% [markdown]
# **tfidf: **function** **
#
# Function tfidf takes 4 arguments:
# 1. vocabular of words
# 2. term frequencies: which is passed in form of a dictionary
# 3. Inverse DF: passed in form of a dictionary
# 4. Collection of all docs passed in form of a dictionary
#
# It returns a dictionary, which is again a dictionary within a dictionary like in case of TF, but it contains score values.

# %%
def tfidf(vocab,tf,idf_scr,doc_dict):
    tf_idf_scr = {}
    for doc_id in doc_dict.keys():
        tf_idf_scr[doc_id] = {}
    for word in vocab:
        for doc_id,doc in doc_dict.items():
            tf_idf_scr[doc_id][word] = tf[doc_id][word] * idf_scr[word]
    return tf_idf_scr

# %% [markdown]
# **vectorSpaceModel: **function** **
#
# To find the relevant documents related to query, pass the query to function alonwith collection of documents (dictionary) and tf-idf scores (dictionary returned by tfidf). Function returns the top 5 documents from a collection of about 22k documents.

# %%
def vectorSpaceModel(query, doc_dict,tfidf_scr):
    query_vocab = []
    for word in query.lower().split():
        if word not in query_vocab:
            query_vocab.append(word)

    query_wc = {}
    for word in query_vocab:
        query_wc[word] = query.lower().split().count(word)
    
    relevance_scores = {}
    for doc_id in doc_dict.keys():
        score = 0
        for word in query_vocab:
            score += query_wc[word] * tfidf_scr[doc_id][word]
        relevance_scores[doc_id] = score
    sorted_value = OrderedDict(sorted(relevance_scores.items(), key=lambda x: x[1], reverse = True))
    top_5 = {k: sorted_value[k] for k in list(sorted_value)[:5]}
    return top_5

# %% [markdown]
# **Testing all the functions above and observe the results.**

# %%
path = 'ACL/*.txt'
docs = give_path(path)                        #returns a dictionary of all docs
M = len(docs)                                 #number of files in dataset
w_List = wordList_removePuncs(docs)           #returns a list of tokenized words
vocab = list(set(w_List))                     #returns a list of unique words
tf_dict = termFrequencyInDoc(vocab, docs)     #returns term frequency
df_dict = wordDocFre(vocab, docs)             #returns document frequencies
idf_dict = inverseDocFre(vocab,df_dict,M)     #returns idf scores
tf_idf = tfidf(vocab,tf_dict,idf_dict,docs)   #returns tf-idf socres

query1 = 'Text Mining'
query2 = 'generative models'
query3 = 'topic modeling'
query4 = 'Natural language Processing'

# %%
len(vocab)
# vocab
# Out:
# 6547

# %%
top1 = vectorSpaceModel(query1, docs,tf_idf)    #returns top 5 documents using VSM
print('Top 5 Documents for Query 1: \n', top1)
# Out:
# Top 5 Documents for Query 1:
#  {'A00-1004.pdf.txt': 60.80930740641406, 'A00-1008.pdf.txt': 10.350905898196757, 'A00-1002.pdf.txt': 9.648063991383243, 'A00-1005.pdf.txt': 8.05374780501027, 'A00-1000.pdf.txt': 3.4594316186372973}

# %%
query1_misspelled="tevt minng"
q=""
for word in query1_misspelled.split():
  q+=spell.correction(word)+" "
  
print("corrected:",q)

top1 = vectorSpaceModel(q, docs,tf_idf)    #returns top 5 documents using VSM
print('Top 5 Documents for Query 1: \n', top1)
# Out:
# corrected: test mining
# Top 5 Documents for Query 1:
#  {'A00-1004.pdf.txt': 45.01105589531213, 'A00-1003.pdf.txt': 10.493629414993691, 'A00-1005.pdf.txt': 6.957308090301861, 'A00-1008.pdf.txt': 5.208369854469579, 'A00-1002.pdf.txt': 4.372345589580705}

# %%
top2 = vectorSpaceModel(query2, docs,tf_idf)    #returns top 5 documents using VSM
print('Top 5 Documents for Query 2: \n', top2)
# Out:
# Top 5 Documents for Query 2:
#  {'A00-1004.pdf.txt': 10.216021330461082, 'A00-1007.pdf.txt': 2.9188632372745946, 'A00-1008.pdf.txt': 1.4594316186372973, 'A00-1005.pdf.txt': 1.4594316186372973, 'A00-1001.pdf.txt': 0.0}

# %%
top3 = vectorSpaceModel(query3, docs,tf_idf)    #returns top 5 documents using VSM
print('Top 5 Documents for Query 3: \n', top3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-42eb47c5d079> in <module>
# ----> 1 top3 = vectorSpaceModel(query3, docs,tf_idf)    #returns top 5 documents using VSM
#       2 print('Top 5 Documents for Query 3: \n', top3)
#
# <ipython-input-19-1e436c88c138> in vectorSpaceModel(query, doc_dict, tfidf_scr)
#      13         score = 0
#      14         for word in query_vocab:
# ---> 15             score += query_wc[word] * tfidf_scr[doc_id][word]
#      16         relevance_scores[doc_id] = score
#      17     sorted_value = OrderedDict(sorted(relevance_scores.items(), key=lambda x: x[1], reverse = True))
#
# KeyError: 'modeling'

# %%
top4 = vectorSpaceModel(query4, docs,tf_idf)    #returns top 5 documents using VSM
print('Top 5 Documents for Query 4: \n', top4)

# %% [markdown]
# # Bigram Language Model

# %% [markdown]
# Load a WhatsApp Chat

# %%
list_of_sentences=[]
f = open("_chat.txt",'r',errors="ignore")

# with open("train_whatsapp.txt",'r',errors="ignore") as input_txt:
for line in f:
  # print(line)
  if("<Speaker 1 Contact Name:>"in line):
    i=line.index("<Speaker 1 Contact Name:>")
    text=line[i+len("<Speaker 1 Contact Name:>"):]
    list_of_sentences.append(line)
  elif("<Speaker 2 Contact Name:>"in line):
    i=line.index("<Speaker 2 Contact Name:>")
    text=line[i+len("<Speaker 2 Contact Name:>"):]
    list_of_sentences.append(text)
  else:
    list_of_sentences.append(line)

# %%
def readData():
    data = list_of_sentences[:2000]
    dat=[]
    for i in range(len(data)):
        for word in data[i].split():
            dat.append(word.lower())
    print(dat)
    return dat

# %%
def createBigram(data):
   listOfBigrams = []
   bigramCounts = {}
   unigramCounts = {}
   for i in range(len(data)-1):
      if i < len(data) - 1 and data[i+1].islower():

         listOfBigrams.append((data[i], data[i + 1]))

         if (data[i], data[i+1]) in bigramCounts:
            bigramCounts[(data[i], data[i + 1])] += 1
         else:
            bigramCounts[(data[i], data[i + 1])] = 1

      if data[i] in unigramCounts:
         unigramCounts[data[i]] += 1
      else:
         unigramCounts[data[i]] = 1
   return listOfBigrams, unigramCounts, bigramCounts

# %%
def calcBigramProb(listOfBigrams, unigramCounts, bigramCounts):
    listOfProb = {}
    for bigram in listOfBigrams:
        word1 = bigram[0]
        word2 = bigram[1]
        listOfProb[bigram] = (bigramCounts.get(bigram))/(unigramCounts.get(word1))
    return listOfProb

# %%
data = readData()
listOfBigrams, unigramCounts, bigramCounts = createBigram(data)

print("\n All the possible Bigrams are ")
print(listOfBigrams)

print("\n Bigrams along with their frequency ")
print(bigramCounts)

print("\n Unigrams along with their frequency ")
print(unigramCounts)

bigramProb = calcBigramProb(listOfBigrams, unigramCounts, bigramCounts)

print("\n Bigrams along with their probability ")
print(bigramProb)
# Out:
# ['\u200emessages', 'and', 'calls', 'are', 'end-to-end', 'encrypted.', 'no', 'one', 'outside', 'of', 'this', 'chat,', 'not', 'even', 'whatsapp,', 'can', 'read', 'or', 'listen', 'to', 'them.', '\u200ethis', 'message', 'was', 'deleted.', '\u200eimage', 'omitted', '\u200eaudio', 'omitted', 'https://www.facebook.com/100000259576988/posts/2137284752956823/', '7aseitek', 'enty', '😂😂', '[10/02/2020,', '10:37:22', 'am]', 'mayar', 'osama:', 'hasm3', 'b3d', 'l', 'lecture', '👌🏻', 'yalla', 'me7tag', 'atlob', '😅', '[10/02/2020,', '12:15:40', 'pm]', 'mayar', 'osama:', 'saniaa', 'aw', 'etlob', 'w', 'law', 'keda', 'hab2a', 'atlob', 'ana', 'm3', 'nafsy', 'howa', 'ana', '7atlob', 'kaman', 'sa3a', 'keda', 'msh', 'delwa2ty', '7alan', 'a2sod', 'bas', '3shan', 'ab2a', 'megamma3', 'el', 'order', 'bera7tek', '[10/02/2020,', '12:23:35', 'pm]', 'mayar', 'osama:', 'ok', '[10/02/2020,', '12:37:22', 'pm]', 'mayar', 'osama:', 'howa', 'momken', 'bl', 'wa7da?', 'howa', 'ana', 'taleb', 'package', 'fa', 'bera7tek', 'shoofy', '3ayza', 'kam', 'bas', 'ah', 'momken', 'bel', 'wa7da', '3ady', '[10/02/2020,', '12:38:47', 'pm]', 'mayar', 'osama:', 'momken', '3', 'tyb', 'ok', '👍🏻', 'flavors', 'eh?', '[10/02/2020,', '1:06:22', 'pm]', 'mayar', 'osama:', 'wa7da', 'peanut', 'butter', 'wa7da', 'nutella', '[10/02/2020,', '1:06:28', 'pm]', 'mayar', 'osama:', 'w', 'lutos', 'ok', '[10/02/2020,', '3:29:27', 'pm]', 'mayar', 'osama:', 'fakrny', 'bs', 'ab2a', 'adik', 'l', 'floos', 'ok', 'ba2olek', 'matenseesh', 'el', '3elba', 'm3aky', 'bokra', '😅', '[11/02/2020,', '11:11:01', 'pm]', 'mayar', 'osama:', 'oh', 'ana', 'nsitha', 'm3', 'islam', '😅😅😅', '[11/02/2020,', '11:11:08', 'pm]', 'mayar', 'osama:', 'bs', 'hagbha', '[11/02/2020,', '11:11:35', 'pm]', 'mayar', 'osama:', 'w', 'bgd', 'thank', 'you', '3l', 'cookies', 'mknsh', 'asdy', 'as5f', 'bs', 'y3ny', '😅😅', 'eshta', 'msh', 'moshkela', 'np', '3ala', 'eh', 'bas', 'el', 'mohem', 'tekoon', '3agabetek', '5aly', 'talabny', 'w', 'sa2alny', '3al', 'feedback', 'beta3ko', '😄', '[11/02/2020,', '11:19:30', 'pm]', 'mayar', 'osama:', 'yes', 'helwa', 'awy', '[11/02/2020,', '11:20:06', 'pm]', 'mayar', 'osama:', 'l', 'chocolate', 'di', 'kant', 'chew', 'awy', 'w', 'fdlt', 'taria', 'which', 'is', 'haga', 'ana', 'b7bha', 'fa', "it's", 'really', 'good', '[11/02/2020,', '11:20:19', 'pm]', 'mayar', 'osama:', 'w', 'khafifa', 'fl', 'akl', 'ohh', 'tab', '7elw', 'el7amdulelah', 'el', 'ba2y', 'lesa', 'hatgarabihom?', '[12/02/2020,', '11:06:22', 'am]', 'mayar', 'osama:', 'howa', 'l', 'tanin', 'mknosh', 'lia', '(one', 'of', 'the', 'reasons', 'why', 'kont', '3iza', 'adik', 'l', 'floos', 'w', 'still)', 'bs', 'im', 'sure', 'n', 'homa', 'kano', 'to7fa', 'brdo', '\u200e[13/02/2020,', '11:48:19', 'am]', 'mayar', 'osama:', '\u200eimage', 'omitted', 'law', '5argeen', 'aw', '7aga', 'momken', 'agy', 'bas', 'ana', 'ma3andeesh', 'tut', 'elnaharda', '[13/02/2020,', '2:40:10', 'pm]', 'mayar', 'osama:', 'oh', 'khlas', 'youm', 'l', '7ad', 'keda', '😅', '\u200eimage', 'omitted', 'esma3y', 'ba2a', "yasser's", 'music', 'f', 'e3dady', '😄', 'eftakartaha', 'embare7', 'w', 'lesa', '3agbany', '😂', '[17/02/2020,', '8:57:30', 'pm]', 'mayar', 'osama:', 'di', 'adima', 'wa7😂😂', '[17/02/2020,', '8:57:43', 'pm]', 'mayar', 'osama:', 'aywa', 'haset', '😂😂😂', '[17/02/2020,', '8:58:10', 'pm]', 'mayar', 'osama:', 'ana', 'btbst', 'awy', 'lama', 'bsm3', 'oghnia', 'adima', 'w', 'ab2a', 'lesa', '7fzha', 'aiwa', 'wana', 'gedan', '😂', 'enty', 'mageteesh', 'elnaharda?', '[25/02/2020,', '8:45:17', 'am]', 'mayar', 'osama:', 'no', 'ro7t', 'bs', 'md5ltsh', 'l', 'quiz', 'fl', 'a5r😅', 'eh', 'dah', 'leh', 'keda', '[25/02/2020,', '2:05:09', 'pm]', 'mayar', 'osama:', 'habal😅😂', '🙃', '[25/02/2020,', '3:02:41', 'pm]', 'mayar', 'osama:', 'makontsh', 'm5lsa', 'mozkra', 'w', 'im', 'stressed', 'asn', '3shan', 'l', 'seminar', 'presentation', 'da', 'olt', 'fakes', 'ana', 'm7tqgq', 'afsl', '[25/02/2020,', '3:03:13', 'pm]', 'mayar', 'osama:', 'so', 'ana', 'ro7t', 'mn', '2nd', 'l7d', '6', 'fl', 'gam3a', '3l', 'fady😂', 'elsara7a ...
#
#  All the possible Bigrams are
# [('\u200emessages', 'and'), ('and', 'calls'), ('calls', 'are'), ('are', 'end-to-end'), ('end-to-end', 'encrypted.'), ('encrypted.', 'no'), ('no', 'one'), ('one', 'outside'), ('outside', 'of'), ('of', 'this'), ('this', 'chat,'), ('chat,', 'not'), ('not', 'even'), ('even', 'whatsapp,'), ('whatsapp,', 'can'), ('can', 'read'), ('read', 'or'), ('or', 'listen'), ('listen', 'to'), ('to', 'them.'), ('them.', '\u200ethis'), ('\u200ethis', 'message'), ('message', 'was'), ('was', 'deleted.'), ('deleted.', '\u200eimage'), ('\u200eimage', 'omitted'), ('omitted', '\u200eaudio'), ('\u200eaudio', 'omitted'), ('omitted', 'https://www.facebook.com/100000259576988/posts/2137284752956823/'), ('https://www.facebook.com/100000259576988/posts/2137284752956823/', '7aseitek'), ('7aseitek', 'enty'), ('10:37:22', 'am]'), ('am]', 'mayar'), ('mayar', 'osama:'), ('osama:', 'hasm3'), ('hasm3', 'b3d'), ('b3d', 'l'), ('l', 'lecture'), ('👌🏻', 'yalla'), ('yalla', 'me7tag'), ('me7tag', 'atlob'), ('12:15:40', 'pm]'), ('pm]', 'mayar'), ('mayar', 'osama:'), ('osama:', 'saniaa'), ('saniaa', 'aw'), ('aw', 'etlob'), ('etlob', 'w'), ('w', 'law'), ('law', 'keda'), ('keda', 'hab2a'), ('hab2a', 'atlob'), ('atlob', 'ana'), ('ana', 'm3'), ('m3', 'nafsy'), ('nafsy', 'howa'), ('howa', 'ana'), ('ana', '7atlob'), ('7atlob', 'kaman'), ('kaman', 'sa3a'), ('sa3a', 'keda'), ('keda', 'msh'), ('msh', 'delwa2ty'), ('delwa2ty', '7alan'), ('7alan', 'a2sod'), ('a2sod', 'bas'), ('bas', '3shan'), ('3shan', 'ab2a'), ('ab2a', 'megamma3'), ('megamma3', 'el'), ('el', 'order'), ('order', 'bera7tek'), ('12:23:35', 'pm]'), ('pm]', 'mayar'), ('mayar', 'osama:'), ('osama:', 'ok'), ('12:37:22', 'pm]'), ('pm]', 'mayar'), ('mayar', 'osama:'), ('osama:', 'howa'), ('howa', 'momken'), ('momken', 'bl'), ('bl', 'wa7da?'), ('wa7da?', 'howa'), ('howa', 'ana'), ('ana', 'taleb'), ('taleb', 'package'), ('package', 'fa'), ('fa', 'bera7tek'), ('bera7tek', 'shoofy'), ('shoofy', '3ayza'), ('3ayza', 'kam'), ('kam', 'bas'), ('bas', 'ah'), ('ah', 'momken'), ('momken', 'bel'), ('bel', 'wa7da'), ('wa7da', '3ady'), ('12:38:47', 'pm]'), ('pm]', 'mayar'), ('mayar', 'osama:'), ('osama:', 'momken'), ('3', 'tyb'), ('tyb', 'ok'), ('👍🏻', 'flavors'), ('flavors', 'eh?'), ('1:06:22', 'pm]'), ('pm]', 'mayar'), ('mayar', 'osama:'), ('osama:', 'wa7da'), ('wa7da', 'peanut'), ('peanut', 'butter'), ('butter', 'wa7da'), ('wa7da', 'nutella'), ('1:06:28', 'pm]'), ('pm]', 'mayar'), ('mayar', 'osama:'), ('osama:', 'w'), ('w', 'lutos'), ('lutos', 'ok'), ('3:29:27', 'pm]'), ('pm]', 'mayar'), ('mayar', 'osama:'), ('osama:', 'fakrny'), ('fakrny', 'bs'), ('bs', 'ab2a'), ('ab2a', 'adik'), ('adik', 'l'), ('l', 'floos'), ('floos', 'ok'), ('ok', 'ba2olek'), ('ba2olek', 'matenseesh'), ('matenseesh', 'el'), ('el', '3elba'), ('3elba', 'm3aky'), ('m3aky', 'bokra'), ('11:11:01', 'pm]'), ('pm]', 'mayar'), ('mayar', 'osama:'), ('osama:', 'oh'), ('oh', 'ana'), ('ana', 'nsitha'), ('nsitha', 'm3'), ('m3', 'islam'), ('11:11:08', 'pm]'), ('pm]', 'mayar'), ('mayar', 'osama:'), ('osama:', 'bs'), ('bs', 'hagbha'), ('11:11:35', 'pm]'), ('pm]', 'mayar'), ('mayar', 'osama:'), ('osama:', 'w'), ('w', 'bgd'), ('bgd', 'thank'), ('thank', 'you'), ('you', '3l'), ('3l', 'cookies'), ('cookies', 'mknsh'), ('mknsh', 'asdy'), ('asdy', 'as5f'), ('as5f', 'bs'), ('bs', 'y3ny'), ('😅😅', 'eshta'), ('eshta', 'msh'), ('msh', 'moshkela'), ('moshkela', 'np'), ('np', '3ala'), ('3ala', 'eh'), ('eh', 'bas'), ('bas', 'el'), ('el', 'mohem'), ('mohem', 'tekoon'), ('tekoon', '3agabetek'), ('3agabetek', '5aly'), ('5aly', 'talabny'), ('talabny', 'w'), ('w', 'sa2alny'), ('sa2alny', '3al'), ('3al', 'feedback'), ('feedback', 'beta3ko'), ('11:19:30', 'pm]'), ('pm]', 'mayar'), ('mayar', 'osama:'), ('osama:', 'yes'), ('yes', 'helwa'), ('helwa', 'awy'), ('11:20:06', 'pm]'), ('pm]', 'mayar'), ('mayar', 'osama:'), ('osama:', 'l'), ('l', 'chocolate'), ('chocolate', 'di'), ('di', 'kant'), ('kant', 'chew'), ('chew', 'awy'), ('awy', 'w'), ('w', 'fdlt'), ('fdlt', 'taria'), ('taria', 'which'), ('which', 'is'), ( ...
#
#  Bigrams along with their frequency
# {('\u200emessages', 'and'): 1, ('and', 'calls'): 1, ('calls', 'are'): 1, ('are', 'end-to-end'): 1, ('end-to-end', 'encrypted.'): 1, ('encrypted.', 'no'): 1, ('no', 'one'): 1, ('one', 'outside'): 1, ('outside', 'of'): 1, ('of', 'this'): 1, ('this', 'chat,'): 1, ('chat,', 'not'): 1, ('not', 'even'): 2, ('even', 'whatsapp,'): 1, ('whatsapp,', 'can'): 1, ('can', 'read'): 1, ('read', 'or'): 1, ('or', 'listen'): 1, ('listen', 'to'): 3, ('to', 'them.'): 1, ('them.', '\u200ethis'): 1, ('\u200ethis', 'message'): 8, ('message', 'was'): 8, ('was', 'deleted.'): 8, ('deleted.', '\u200eimage'): 1, ('\u200eimage', 'omitted'): 40, ('omitted', '\u200eaudio'): 6, ('\u200eaudio', 'omitted'): 72, ('omitted', 'https://www.facebook.com/100000259576988/posts/2137284752956823/'): 1, ('https://www.facebook.com/100000259576988/posts/2137284752956823/', '7aseitek'): 1, ('7aseitek', 'enty'): 1, ('10:37:22', 'am]'): 1, ('am]', 'mayar'): 277, ('mayar', 'osama:'): 902, ('osama:', 'hasm3'): 1, ('hasm3', 'b3d'): 1, ('b3d', 'l'): 5, ('l', 'lecture'): 2, ('👌🏻', 'yalla'): 1, ('yalla', 'me7tag'): 1, ('me7tag', 'atlob'): 1, ('12:15:40', 'pm]'): 1, ('pm]', 'mayar'): 625, ('osama:', 'saniaa'): 1, ('saniaa', 'aw'): 1, ('aw', 'etlob'): 1, ('etlob', 'w'): 1, ('w', 'law'): 3, ('law', 'keda'): 4, ('keda', 'hab2a'): 1, ('hab2a', 'atlob'): 1, ('atlob', 'ana'): 1, ('ana', 'm3'): 1, ('m3', 'nafsy'): 2, ('nafsy', 'howa'): 1, ('howa', 'ana'): 14, ('ana', '7atlob'): 1, ('7atlob', 'kaman'): 1, ('kaman', 'sa3a'): 1, ('sa3a', 'keda'): 2, ('keda', 'msh'): 1, ('msh', 'delwa2ty'): 1, ('delwa2ty', '7alan'): 1, ('7alan', 'a2sod'): 1, ('a2sod', 'bas'): 1, ('bas', '3shan'): 1, ('3shan', 'ab2a'): 1, ('ab2a', 'megamma3'): 1, ('megamma3', 'el'): 1, ('el', 'order'): 1, ('order', 'bera7tek'): 1, ('12:23:35', 'pm]'): 1, ('osama:', 'ok'): 2, ('12:37:22', 'pm]'): 1, ('osama:', 'howa'): 25, ('howa', 'momken'): 1, ('momken', 'bl'): 1, ('bl', 'wa7da?'): 1, ('wa7da?', 'howa'): 1, ('ana', 'taleb'): 1, ('taleb', 'package'): 1, ('package', 'fa'): 1, ('fa', 'bera7tek'): 1, ('bera7tek', 'shoofy'): 1, ('shoofy', '3ayza'): 1, ('3ayza', 'kam'): 1, ('kam', 'bas'): 1, ('bas', 'ah'): 4, ('ah', 'momken'): 1, ('momken', 'bel'): 1, ('bel', 'wa7da'): 1, ('wa7da', '3ady'): 1, ('12:38:47', 'pm]'): 1, ('osama:', 'momken'): 3, ('3', 'tyb'): 1, ('tyb', 'ok'): 1, ('👍🏻', 'flavors'): 1, ('flavors', 'eh?'): 1, ('1:06:22', 'pm]'): 1, ('osama:', 'wa7da'): 1, ('wa7da', 'peanut'): 1, ('peanut', 'butter'): 1, ('butter', 'wa7da'): 1, ('wa7da', 'nutella'): 1, ('1:06:28', 'pm]'): 1, ('osama:', 'w'): 12, ('w', 'lutos'): 1, ('lutos', 'ok'): 1, ('3:29:27', 'pm]'): 1, ('osama:', 'fakrny'): 1, ('fakrny', 'bs'): 1, ('bs', 'ab2a'): 1, ('ab2a', 'adik'): 1, ('adik', 'l'): 2, ('l', 'floos'): 2, ('floos', 'ok'): 1, ('ok', 'ba2olek'): 1, ('ba2olek', 'matenseesh'): 1, ('matenseesh', 'el'): 1, ('el', '3elba'): 1, ('3elba', 'm3aky'): 1, ('m3aky', 'bokra'): 1, ('11:11:01', 'pm]'): 1, ('osama:', 'oh'): 6, ('oh', 'ana'): 1, ('ana', 'nsitha'): 1, ('nsitha', 'm3'): 1, ('m3', 'islam'): 1, ('11:11:08', 'pm]'): 1, ('osama:', 'bs'): 29, ('bs', 'hagbha'): 1, ('11:11:35', 'pm]'): 1, ('w', 'bgd'): 2, ('bgd', 'thank'): 1, ('thank', 'you'): 9, ('you', '3l'): 1, ('3l', 'cookies'): 1, ('cookies', 'mknsh'): 1, ('mknsh', 'asdy'): 1, ('asdy', 'as5f'): 1, ('as5f', 'bs'): 1, ('bs', 'y3ny'): 1, ('😅😅', 'eshta'): 1, ('eshta', 'msh'): 1, ('msh', 'moshkela'): 1, ('moshkela', 'np'): 1, ('np', '3ala'): 1, ('3ala', 'eh'): 5, ('eh', 'bas'): 4, ('bas', 'el'): 6, ('el', 'mohem'): 3, ('mohem', 'tekoon'): 1, ('tekoon', '3agabetek'): 1, ('3agabetek', '5aly'): 1, ('5aly', 'talabny'): 1, ('talabny', 'w'): 1, ('w', 'sa2alny'): 1, ('sa2alny', '3al'): 1, ('3al', 'feedback'): 1, ('feedback', 'beta3ko'): 1, ('11:19:30', 'pm]'): 1, ('osama:', 'yes'): 14, ('yes', 'helwa'): 1, ('helwa', 'awy'): 2, ('11:20:06', 'pm]'): 1, ('osama:', 'l'): 11, ('l', 'chocolate'): 1, ('chocolate', 'di'): 1, ('di', 'kant'): 2, ('kant', 'chew'): 1, ('chew', 'awy'): 1, ('awy', 'w'): 2, ('w', 'fdlt'): 1, ('fdlt', ...
#
#  Unigrams along with their frequency
# {'\u200emessages': 1, 'and': 31, 'calls': 1, 'are': 4, 'end-to-end': 1, 'encrypted.': 1, 'no': 27, 'one': 6, 'outside': 1, 'of': 13, 'this': 25, 'chat,': 1, 'not': 18, 'even': 5, 'whatsapp,': 1, 'can': 9, 'read': 1, 'or': 6, 'listen': 3, 'to': 37, 'them.': 1, '\u200ethis': 8, 'message': 8, 'was': 15, 'deleted.': 8, '\u200eimage': 40, 'omitted': 132, '\u200eaudio': 72, 'https://www.facebook.com/100000259576988/posts/2137284752956823/': 1, '7aseitek': 1, 'enty': 35, '😂😂': 41, '[10/02/2020,': 8, '10:37:22': 1, 'am]': 277, 'mayar': 909, 'osama:': 902, 'hasm3': 1, 'b3d': 9, 'l': 191, 'lecture': 8, '👌🏻': 14, 'yalla': 9, 'me7tag': 2, 'atlob': 2, '😅': 109, '12:15:40': 1, 'pm]': 625, 'saniaa': 1, 'aw': 62, 'etlob': 1, 'w': 160, 'law': 63, 'keda': 117, 'hab2a': 4, 'ana': 170, 'm3': 18, 'nafsy': 5, 'howa': 80, '7atlob': 1, 'kaman': 12, 'sa3a': 9, 'msh': 124, 'delwa2ty': 7, '7alan': 1, 'a2sod': 1, 'bas': 89, '3shan': 49, 'ab2a': 10, 'megamma3': 1, 'el': 165, 'order': 4, 'bera7tek': 4, '12:23:35': 1, 'ok': 21, '12:37:22': 1, 'momken': 30, 'bl': 7, 'wa7da?': 1, 'taleb': 1, 'package': 1, 'fa': 51, 'shoofy': 2, '3ayza': 4, 'kam': 10, 'ah': 72, 'bel': 4, 'wa7da': 3, '3ady': 24, '12:38:47': 1, '3': 7, 'tyb': 3, '👍🏻': 11, 'flavors': 2, 'eh?': 13, '1:06:22': 1, 'peanut': 1, 'butter': 1, 'nutella': 1, '1:06:28': 1, 'lutos': 1, '3:29:27': 1, 'fakrny': 1, 'bs': 93, 'adik': 2, 'floos': 3, 'ba2olek': 8, 'matenseesh': 1, '3elba': 1, 'm3aky': 5, 'bokra': 23, '[11/02/2020,': 6, '11:11:01': 1, 'oh': 6, 'nsitha': 1, 'islam': 1, '😅😅😅': 4, '11:11:08': 1, 'hagbha': 1, '11:11:35': 1, 'bgd': 35, 'thank': 11, 'you': 67, '3l': 10, 'cookies': 3, 'mknsh': 3, 'asdy': 1, 'as5f': 1, 'y3ny': 5, '😅😅': 6, 'eshta': 19, 'moshkela': 4, 'np': 1, '3ala': 14, 'eh': 108, 'mohem': 3, 'tekoon': 1, '3agabetek': 1, '5aly': 1, 'talabny': 1, 'sa2alny': 1, '3al': 13, 'feedback': 1, 'beta3ko': 1, '😄': 31, '11:19:30': 1, 'yes': 15, 'helwa': 6, 'awy': 17, '11:20:06': 1, 'chocolate': 1, 'di': 23, 'kant': 7, 'chew': 1, 'fdlt': 1, 'taria': 1, 'which': 2, 'is': 36, 'haga': 56, 'b7bha': 1, "it's": 6, 'really': 7, 'good': 29, '11:20:19': 1, 'khafifa': 1, 'fl': 27, 'akl': 3, 'ohh': 5, 'tab': 23, '7elw': 11, 'el7amdulelah': 23, 'ba2y': 1, 'lesa': 26, 'hatgarabihom?': 1, '[12/02/2020,': 1, '11:06:22': 1, 'tanin': 1, 'mknosh': 1, 'lia': 2, '(one': 1, 'the': 38, 'reasons': 1, 'why': 7, 'kont': 40, '3iza': 13, 'still)': 1, 'im': 16, 'sure': 5, 'n': 23, 'homa': 3, 'kano': 3, 'to7fa': 9, 'brdo': 3, '\u200e[13/02/2020,': 1, '11:48:19': 1, '5argeen': 2, '7aga': 32, 'agy': 3, 'ma3andeesh': 1, 'tut': 3, 'elnaharda': 10, '[13/02/2020,': 1, '2:40:10': 1, 'khlas': 4, 'youm': 6, '7ad': 7, 'esma3y': 1, 'ba2a': 28, "yasser's": 1, 'music': 8, 'f': 49, 'e3dady': 1, 'eftakartaha': 1, 'embare7': 7, '3agbany': 1, '😂': 139, '[17/02/2020,': 3, '8:57:30': 1, 'adima': 2, 'wa7😂😂': 1, '8:57:43': 1, 'aywa': 6, 'haset': 1, '😂😂😂': 23, '8:58:10': 1, 'btbst': 1, 'lama': 11, 'bsm3': 2, 'oghnia': 1, '7fzha': 1, 'aiwa': 9, 'wana': 16, 'gedan': 8, 'mageteesh': 1, 'elnaharda?': 3, '[25/02/2020,': 10, '8:45:17': 1, 'ro7t': 4, 'md5ltsh': 1, 'quiz': 4, 'a5r😅': 1, 'dah': 67, 'leh': 11, '2:05:09': 1, 'habal😅😂': 1, '🙃': 2, '3:02:41': 1, 'makontsh': 1, 'm5lsa': 1, 'mozkra': 2, 'stressed': 1, 'asn': 1, 'seminar': 2, 'presentation': 3, 'da': 39, 'olt': 6, 'fakes': 2, 'm7tqgq': 1, 'afsl': 1, '3:03:13': 1, 'so': 23, 'mn': 19, '2nd': 1, 'l7d': 5, '6': 4, 'gam3a': 7, 'fady😂': 1, 'elsara7a': 18, 'kan': 18, 'elmafrood': 4, 'yeb2a': 8, 'beta3y': 2, '5ayef': 4, "mayetle3'eesh": 1, 'makontesh': 5, 'gahez': 1, 'habal': 1, '3:44:09': 1, 'lucky': 1, '3:44:14': 1, 'habal😂': 1, '3:44:53': 1, 'khlast': 1, 'bzbt': 4, 'fiha': 7, 'tl3t': 1, 'lel': 10, 'dr': 4, '(howa': 1, 'ro7tlo': 1, 'tany': 7, 'mara': 4, 'laptop': 8, 'mwgoud': 1, 'stl)': 1, '3:45:03': 1, 'bngz': 1, 'gm3a': 1, '3n': 7, 'l.bet': 1, 'mashy': 9, '🤷🏻\u200d♂': 1, 'gahza?': 1, '\u200e[25/02/2020,': 1, '3:45:45': 1, '3:46:03': 1, 'hia': 14, 'ed3iliana': 1, 'aya': 1, 'b2a': 6, 'templates': 1, 'rews ...
#
#  Bigrams along with their probability
# {('\u200emessages', 'and'): 1.0, ('and', 'calls'): 0.03225806451612903, ('calls', 'are'): 1.0, ('are', 'end-to-end'): 0.25, ('end-to-end', 'encrypted.'): 1.0, ('encrypted.', 'no'): 1.0, ('no', 'one'): 0.037037037037037035, ('one', 'outside'): 0.16666666666666666, ('outside', 'of'): 1.0, ('of', 'this'): 0.07692307692307693, ('this', 'chat,'): 0.04, ('chat,', 'not'): 1.0, ('not', 'even'): 0.1111111111111111, ('even', 'whatsapp,'): 0.2, ('whatsapp,', 'can'): 1.0, ('can', 'read'): 0.1111111111111111, ('read', 'or'): 1.0, ('or', 'listen'): 0.16666666666666666, ('listen', 'to'): 1.0, ('to', 'them.'): 0.02702702702702703, ('them.', '\u200ethis'): 1.0, ('\u200ethis', 'message'): 1.0, ('message', 'was'): 1.0, ('was', 'deleted.'): 0.5333333333333333, ('deleted.', '\u200eimage'): 0.125, ('\u200eimage', 'omitted'): 1.0, ('omitted', '\u200eaudio'): 0.045454545454545456, ('\u200eaudio', 'omitted'): 1.0, ('omitted', 'https://www.facebook.com/100000259576988/posts/2137284752956823/'): 0.007575757575757576, ('https://www.facebook.com/100000259576988/posts/2137284752956823/', '7aseitek'): 1.0, ('7aseitek', 'enty'): 1.0, ('10:37:22', 'am]'): 1.0, ('am]', 'mayar'): 1.0, ('mayar', 'osama:'): 0.9922992299229924, ('osama:', 'hasm3'): 0.0011086474501108647, ('hasm3', 'b3d'): 1.0, ('b3d', 'l'): 0.5555555555555556, ('l', 'lecture'): 0.010471204188481676, ('👌🏻', 'yalla'): 0.07142857142857142, ('yalla', 'me7tag'): 0.1111111111111111, ('me7tag', 'atlob'): 0.5, ('12:15:40', 'pm]'): 1.0, ('pm]', 'mayar'): 1.0, ('osama:', 'saniaa'): 0.0011086474501108647, ('saniaa', 'aw'): 1.0, ('aw', 'etlob'): 0.016129032258064516, ('etlob', 'w'): 1.0, ('w', 'law'): 0.01875, ('law', 'keda'): 0.06349206349206349, ('keda', 'hab2a'): 0.008547008547008548, ('hab2a', 'atlob'): 0.25, ('atlob', 'ana'): 0.5, ('ana', 'm3'): 0.0058823529411764705, ('m3', 'nafsy'): 0.1111111111111111, ('nafsy', 'howa'): 0.2, ('howa', 'ana'): 0.175, ('ana', '7atlob'): 0.0058823529411764705, ('7atlob', 'kaman'): 1.0, ('kaman', 'sa3a'): 0.08333333333333333, ('sa3a', 'keda'): 0.2222222222222222, ('keda', 'msh'): 0.008547008547008548, ('msh', 'delwa2ty'): 0.008064516129032258, ('delwa2ty', '7alan'): 0.14285714285714285, ('7alan', 'a2sod'): 1.0, ('a2sod', 'bas'): 1.0, ('bas', '3shan'): 0.011235955056179775, ('3shan', 'ab2a'): 0.02040816326530612, ('ab2a', 'megamma3'): 0.1, ('megamma3', 'el'): 1.0, ('el', 'order'): 0.006060606060606061, ('order', 'bera7tek'): 0.25, ('12:23:35', 'pm]'): 1.0, ('osama:', 'ok'): 0.0022172949002217295, ('12:37:22', 'pm]'): 1.0, ('osama:', 'howa'): 0.02771618625277162, ('howa', 'momken'): 0.0125, ('momken', 'bl'): 0.03333333333333333, ('bl', 'wa7da?'): 0.14285714285714285, ('wa7da?', 'howa'): 1.0, ('ana', 'taleb'): 0.0058823529411764705, ('taleb', 'package'): 1.0, ('package', 'fa'): 1.0, ('fa', 'bera7tek'): 0.0196078431372549, ('bera7tek', 'shoofy'): 0.25, ('shoofy', '3ayza'): 0.5, ('3ayza', 'kam'): 0.25, ('kam', 'bas'): 0.1, ('bas', 'ah'): 0.0449438202247191, ('ah', 'momken'): 0.013888888888888888, ('momken', 'bel'): 0.03333333333333333, ('bel', 'wa7da'): 0.25, ('wa7da', '3ady'): 0.3333333333333333, ('12:38:47', 'pm]'): 1.0, ('osama:', 'momken'): 0.0033259423503325942, ('3', 'tyb'): 0.14285714285714285, ('tyb', 'ok'): 0.3333333333333333, ('👍🏻', 'flavors'): 0.09090909090909091, ('flavors', 'eh?'): 0.5, ('1:06:22', 'pm]'): 1.0, ('osama:', 'wa7da'): 0.0011086474501108647, ('wa7da', 'peanut'): 0.3333333333333333, ('peanut', 'butter'): 1.0, ('butter', 'wa7da'): 1.0, ('wa7da', 'nutella'): 0.3333333333333333, ('1:06:28', 'pm]'): 1.0, ('osama:', 'w'): 0.013303769401330377, ('w', 'lutos'): 0.00625, ('lutos', 'ok'): 1.0, ('3:29:27', 'pm]'): 1.0, ('osama:', 'fakrny'): 0.0011086474501108647, ('fakrny', 'bs'): 1.0, ('bs', 'ab2a'): 0.010752688172043012, ('ab2a', 'adik'): 0.1, ('adik', 'l'): 1.0, ('l', 'floos'): 0.010471204188481676, ('floos', 'ok'): 0.3333333333333333, ('ok', 'ba2olek'): 0.047619047619047616, ('ba2olek', 'matenseesh'): 0.125, ('matenseesh', 'el'): 1.0, ('el', '3elba'): 0.00606 ...

# %%
# Generate Sentence
# Set lenghth of the sentence to 10
max_len=15
# Start word
current="hello"
s=current+" "
for i in range(max_len):
  list_bigrams={}
  # print("current word ", current)
  for key_tuple in bigramProb.keys():
    
  # Use the current word to see what is the most frequent word to follow it
    if current in key_tuple[0].split():
      # Save list of all bigrams where the current word first appears
      list_bigrams[bigramProb[key_tuple]]=key_tuple
  # print("list_bigrams",list_bigrams)
  # get the highest probability bigram for the current word
  max_=max(list_bigrams.keys())
  max_bigram=list_bigrams[max_]
  # set the current word with the highest prob word for the next iteration
  current=max_bigram[1]
  # append to the sentence
  s+=max_bigram[1]+" "
print("Generated Sentence ",s)
# Out:
# Generated Sentence  hello i love it to save it to save it to save it to save it

# %%
inputList="eh el a5abar"
# inputList=correct(inputList)
splt=inputList.lower().split()
outputProb1 = 1
bilist=[]
bigrm=[]

for i in range(len(splt) - 1):
    if i < len(splt) - 1:
        bilist.append((splt[i], splt[i + 1]))

print("\n The bigrams in given sentence are ")
print(bilist)
for i in range(len(bilist)):
    if bilist[i] in bigramProb:
      print(bilist[i],bigramProb[bilist[i]])
      outputProb1 *= bigramProb[bilist[i]]
    else:
        outputProb1 *= 0.0
print('\n' + 'Probablility of sentence '+inputList+' = ' + str(outputProb1))

# %% [markdown]
# # Extra Excercise

# %% [markdown]
# For this excercise you should use the bigram model to generate the correct candidates for the personalized spelling checker
# Hint: use the probability as your context to decide on the correct replacment

# %%
# Add your code here

# %% [markdown]
# Since term matching is not an easy task for TFIDF systems, try and find the correct synonyms/antonyms that would help you pick the correct query for the retrival model
#
# Hint: use NLTK WordNet

# %%
# Add your code here

# %% [markdown]
# # Additional Resources

# %% [markdown]
# [fuzzywuzzy](https://www.geeksforgeeks.org/fuzzywuzzy-python-library/)
#
# [String matching with fuzzywuzzy](https://towardsdatascience.com/string-matching-with-fuzzywuzzy-e982c61f8a84)
#
# [Levenshtein_distance](https://en.wikipedia.org/wiki/Levenshtein_distance)
#
# [DrQA](https://github.com/facebookresearch/DrQA)
# "DrQA adopts bi-gram hashing and TF-IDF matching to search over Wikipedia, given a natural language question."
#
#
# [How to compute text similarity on a website with TF-IDF in Python](https://towardsdatascience.com/how-to-compute-text-similarity-on-a-website-with-tf-idf-in-python-680b3be06091)
#
# [How to scrape a blog and collect its articles in Python](https://medium.com/mlearning-ai/how-to-scrape-a-blog-and-collect-its-articles-in-python-80895d8def66)
